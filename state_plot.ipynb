# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import json
import altair as alt
import ipywidgets as widgets

# %%
df_FL = pd.read_csv(
    'https://raw.githubusercontent.com/yuwei97910/is445-group30-final-project/main/DataSet/yelp_academic_dataset_business_FL.csv')
df_FL.head()
# Out:
#    Unnamed: 0             business_id                   name  \
# 0           0  qkRM_2X51Yqxk3btlwAQIg         Temple Beth-El
# 1           1  UJsufbvfyfONHeWdvAHKjA              Marshalls
# 2           2  eEOYSgkmpB90uNA7lDOMRA  Vietnamese Food Truck
# 3           3  jaxMSoInw8Poo3XeMJt8lQ           Adams Dental
# 4           4  0bPLkL0QhhPO5kt1_EXmNQ   Zio's Italian Market
#
#                      address            city state  postal_code   latitude  \
# 0         400 Pasadena Ave S  St. Petersburg    FL      33707.0  27.766590
# 1  21705 Village Lakes Sc Dr   Land O' Lakes    FL      34639.0  28.190459
# 2                        NaN       Tampa Bay    FL      33602.0  27.955269
# 3          15 N Missouri Ave      Clearwater    FL      33755.0  27.966235
# 4              2575 E Bay Dr           Largo    FL      33771.0  27.916116
#
#    longitude  stars  ...  has_wifi  has_parking animal_friendly Monday  \
# 0 -82.732983    3.5  ...     False        False           False    8.0
# 1 -82.457380    3.5  ...     False        False           False   12.0
# 2 -82.456320    4.0  ...     False        False           False    3.0
# 3 -82.787412    5.0  ...     False        False           False    8.0
# 4 -82.760461    4.5  ...      True         True           False    8.0
#
#   Tuesday Wednesday Thursday Friday  Saturday  Sunday
# 0     8.0       8.0      8.0    8.0       NaN     NaN
# 1    12.0      12.0     12.0   12.0      12.0    10.0
# 2     3.0       3.0      3.0    3.0       5.0     3.0
# 3     8.0       8.0      8.0    NaN       NaN     NaN
# 4    10.0      10.0     10.0   10.0      10.0     NaN
#
# [5 rows x 28 columns]

# %%
alt.data_transformers.enable('json')
chart = alt.Chart(df_FL).mark_circle().encode(
    x='longitude:Q',
    y='latitude:Q',
    tooltip='name',
    color=alt.Color('stars')
).interactive()

points = alt.Chart(df_FL).mark_circle().encode(
    longitude='longitude:Q',
    latitude='latitude:Q',
    size=alt.value(10),
    tooltip='name'
)

chart.display()
# Out:
# alt.Chart(...)

# %%
df_FL.head()
# Out:
#    Unnamed: 0             business_id                   name  \
# 0           0  qkRM_2X51Yqxk3btlwAQIg         Temple Beth-El
# 1           1  UJsufbvfyfONHeWdvAHKjA              Marshalls
# 2           2  eEOYSgkmpB90uNA7lDOMRA  Vietnamese Food Truck
# 3           3  jaxMSoInw8Poo3XeMJt8lQ           Adams Dental
# 4           4  0bPLkL0QhhPO5kt1_EXmNQ   Zio's Italian Market
#
#                      address            city state  postal_code   latitude  \
# 0         400 Pasadena Ave S  St. Petersburg    FL      33707.0  27.766590
# 1  21705 Village Lakes Sc Dr   Land O' Lakes    FL      34639.0  28.190459
# 2                        NaN       Tampa Bay    FL      33602.0  27.955269
# 3          15 N Missouri Ave      Clearwater    FL      33755.0  27.966235
# 4              2575 E Bay Dr           Largo    FL      33771.0  27.916116
#
#    longitude  stars  ...  has_wifi  has_parking animal_friendly Monday  \
# 0 -82.732983    3.5  ...     False        False           False    8.0
# 1 -82.457380    3.5  ...     False        False           False   12.0
# 2 -82.456320    4.0  ...     False        False           False    3.0
# 3 -82.787412    5.0  ...     False        False           False    8.0
# 4 -82.760461    4.5  ...      True         True           False    8.0
#
#   Tuesday Wednesday Thursday Friday  Saturday  Sunday
# 0     8.0       8.0      8.0    8.0       NaN     NaN
# 1    12.0      12.0     12.0   12.0      12.0    10.0
# 2     3.0       3.0      3.0    3.0       5.0     3.0
# 3     8.0       8.0      8.0    NaN       NaN     NaN
# 4    10.0      10.0     10.0   10.0      10.0     NaN
#
# [5 rows x 28 columns]

# %%
from vega_datasets import data

states = alt.topo_feature(data.us_10m.url, feature='states')
airports = data.airports()

background = alt.Chart(states).mark_geoshape(
    fill='lightgray',
    stroke='white'
).project('albersUsa').properties(
    width=500,
    height=300
)

points = alt.Chart(df_FL).mark_circle().encode(
    longitude='longitude:Q',
    latitude='latitude:Q',
    size=alt.value(10),
    tooltip='name'
)

background + points
# Out:
# alt.LayerChart(...)

# %%
chart = alt.Chart.from_dict({
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "width": 800,
    "height": 500,
    "projection": {
        "type": "albersUsa"
    },
    "layer": [
        {
            "data": {
                # "url": "https://raw.githubusercontent.com/vega/vega/main/docs/data/us-10m.json",
                "url": "https://raw.githubusercontent.com/unitedstates/districts/gh-pages/states/FL/shape.geojson",
                "format": {
                "type": "topojson",
                "feature": "states"
                }
            },
            "mark": {
                "type": "geoshape",
                "fill": "lightgray",
                "stroke": "white",
                "clip": True
            }
        },
        {
            "data": {"url": "https://raw.githubusercontent.com/yuwei97910/is445-group30-final-project/main/DataSet/yelp_academic_dataset_business_FL.csv"},
            "mark": {"type": "circle", "clip": True},
            "encoding": {
                "longitude": {"field": "longitude", "type": "quantitative"},
                "latitude": {"field": "latitude", 'type': "quantitative"},
            }
        },
    ]
})

chart.display()
# Out:
# alt.LayerChart(...)

# %%
states = alt.topo_feature("https://raw.githubusercontent.com/unitedstates/districts/gh-pages/states/FL/shape.geojson", feature='states')
# airports = data.airports()

# background = alt.Chart(states).mark_geoshape(
#     fill='lightgray',
#     stroke='white'
# ).project('albersUsa').properties(
#     width=500,
#     height=300
# )

points = alt.Chart(df_FL).mark_circle().encode(
    longitude='longitude:Q',
    latitude='latitude:Q',
    size=alt.value(10),
    tooltip='name'
).interactive()

# background + points
# background
points
# Out:
# ---------------------------------------------------------------------------
# MaxRowsError                              Traceback (most recent call last)
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/altair/vegalite/v4/api.py in to_dict(self, *args, **kwargs)
#    2018             copy.data = core.InlineData(values=[{}])
#    2019             return super(Chart, copy).to_dict(*args, **kwargs)
# -> 2020         return super().to_dict(*args, **kwargs)
#    2021
#    2022     def add_selection(self, *selections):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/altair/vegalite/v4/api.py in to_dict(self, *args, **kwargs)
#     372         copy = self.copy(deep=False)
#     373         original_data = getattr(copy, "data", Undefined)
# --> 374         copy.data = _prepare_data(original_data, context)
#     375
#     376         if original_data is not Undefined:
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/altair/vegalite/v4/api.py in _prepare_data(data, context)
#      87     # convert dataframes  or objects with __geo_interface__ to dict
#      88     if isinstance(data, pd.DataFrame) or hasattr(data, "__geo_interface__"):
# ---> 89         data = _pipe(data, data_transformers.get())
#      90
#      91     # convert string input to a URLData
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/toolz/functoolz.py in pipe(data, *funcs)
#     626     """
#     627     for func in funcs:
# --> 628         data = func(data)
#     629     return data
#     630
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/toolz/functoolz.py in __call__(self, *args, **kwargs)
#     302     def __call__(self, *args, **kwargs):
#     303         try:
# --> 304             return self._partial(*args, **kwargs)
#     305         except TypeError as exc:
#     306             if self._should_curry(args, kwargs, exc):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/altair/vegalite/data.py in default_data_transformer(data, max_rows)
#      17 @curried.curry
#      18 def default_data_transformer(data, max_rows=5000):
# ---> 19     return curried.pipe(data, limit_rows(max_rows=max_rows), to_values)
#      20
#      21
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/toolz/functoolz.py in pipe(data, *funcs)
#     626     """
#     627     for func in funcs:
# --> 628         data = func(data)
#     629     return data
#     630
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/toolz/functoolz.py in __call__(self, *args, **kwargs)
#     302     def __call__(self, *args, **kwargs):
#     303         try:
# --> 304             return self._partial(*args, **kwargs)
#     305         except TypeError as exc:
#     306             if self._should_curry(args, kwargs, exc):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/altair/utils/data.py in limit_rows(data, max_rows)
#      82             "than the maximum allowed ({}). "
#      83             "For information on how to plot larger datasets "
# ---> 84             "in Altair, see the documentation".format(max_rows)
#      85         )
#      86     return data
#
# MaxRowsError: The number of rows in your dataset is greater than the maximum allowed (5000). For information on how to plot larger datasets in Altair, see the documentation
# alt.Chart(...)

# %%
chart = alt.Chart.from_dict({
    "data": {"url": "https://raw.githubusercontent.com/yuwei97910/is445-group30-final-project/main/DataSet/yelp_academic_dataset_business_FL.csv"},
    "mark": {"type": "point", "clip": True, "tooltip": {"content": "data"}},
    "projection": {
        "type": "albersUsa"
    },
    "encoding": {
        # "x": {"field": "longitude", "type": "quantitative", "scale": {"domain": [-83, -82]}},
        "x": {"field": "longitude", "type": "quantitative"},
        # "y": {"field": "latitude", 'type': "quantitative", "scale": {"domain": [27, 28.5]}},
        "y": {"field": "latitude", 'type': "quantitative"},
        'color': {'value': "orange"},
    }
}).interactive()
chart.display()
# Out:
# alt.Chart(...)

# %%
chart = alt.Chart.from_dict({
    "data": {"url": "https://raw.githubusercontent.com/yuwei97910/is445-group30-final-project/main/DataSet/yelp_academic_dataset_business_FL.csv"},
    "mark": "bar",
    "encoding": {
        "x": {"field": "stars", "type": "quantitative"},
        "y": {"aggregate": "count", "field": "latitude", 'type': "quantitative"},
        'color': {'value': "orange"},
    }})
chart.display()
# Out:
# alt.Chart(...)

# %%
ys = ['review_count', 'Monday', 'Tuesday', 'Wednesday',
      'Thursday', 'Friday', 'Saturday', 'review_count']

select_box = alt.binding_select(options=ys, name='y_axis')
sel_y = alt.selection_single(
    fields=['y_axis'], bind=select_box, init={'y_axis': 'Monday'})

# xs = ['stars', 'review_count']

# select_box = alt.binding_select(options=xs, name='x_axis')
# sel_x = alt.selection_single(fields=['x_axis'], bind=select_box, init={'x_axis': 'stars'})


chart = alt.Chart(df_IL).transform_fold(
    ys,
    as_=['y_axis', 'y_value']
).mark_circle().encode(
    x='stars:Q',
    y='y_value:Q',
    tooltip='name',
    color=alt.Color('stars:Q')
).add_selection(
    sel_y,
).transform_filter(
    sel_y
).interactive()
chart.display()
chart.save("test_altair.html")

# %%
df_geo = pd.read_json('https://eric.clst.org/assets/wiki/uploads/Stuff/gz_2010_us_040_00_20m.json')
df_geo.head()
# Out:
#                 type                                           features
# 0  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 1  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 2  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 3  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 4  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
